# %%
# classical ML
''' To train machine, ML is an art of programming computers so they can learn the data ML Models KVM,SVM, Linear Regression for prediction & analysis'''

# %%
#slope y=mx+b
''' ek line draw krta or data ko uske according chack krta'''
# Out:
# 'slope y=mx+b'

# %% [markdown]
# # House price prediction

# %%
import pandas as pd

# %%
df = pd.read_csv('ksCZiA.csv')

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# !pip install sklearn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --------------------- ------------------ 4.7/8.7 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 25.1 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
plt.scatter(df.area,df.price, color='red', marker = '+')

# %%
# Regression ---> straight line on scatter graph
'''y = mx #price = slop*area = y-intercept
y = price
x = area
m = slope
y = intersection'''
# Out:
# 'y = mx #price = slop*area = y-intercept\ny = price\nx = area\nm = slope\ny = intersection'

# %%
new_df = df.drop('price', axis = 'columns')

# %%
price = df.price

# %%
#creating object
reg = linear_model.LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(new_df, price)
# Out:
# LinearRegression()

# %%
reg.predict([[5500],[56000]])
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 927448.63013699, 7784726.02739726])

# %%
new_df2 = df.drop('area', axis = 'columns')

# %%
new_df2
# Out:
#     price
# 0  550000
# 1  565000
# 2  610000
# 3  680000
# 4  725000

# %%
area = df.area

# %%
reg2 = linear_model.LinearRegression()

# %%
reg2.fit(new_df2,area)
# Out:
# LinearRegression()

# %%
#corelation ---> m slope

# %%
# y- intercept ---> x=o
# x- intercept ---> y=0
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
reg.predict([[5000]])
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
135.78767123*5000 + 180616.43835616432
# Out:
# 859554.7945061643
