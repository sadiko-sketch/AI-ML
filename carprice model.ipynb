# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import math
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('ptRnnW.csv')

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
df.info('carlength')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %% [markdown]
# # CAR PRICE PREDICTION

# %%
df.sort_values(by=['CarName','horsepower','price'], ascending=False)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 190     191          3                 vw rabbit      gas        std
# 189     190          3                 vw dasher      gas        std
# 199     200         -1              volvo diesel      gas      turbo
# 198     199         -2               volvo 264gl      gas      turbo
# 204     205         -1               volvo 264gl      gas      turbo
# ..      ...        ...                       ...      ...        ...
# 3         4          2               audi 100 ls      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 0         1          3        alfa-romero giulia      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 89       90          1              Nissan versa      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
# !pip install word2number
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from word2number import w2n
df['doornumber']=df['doornumber'].apply(w2n.word_to_num)
df['doornumber']
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: doornumber, Length: 205, dtype: int64

# %%
df['price'].astype(int)
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int64

# %%
df1=df.drop(columns=['car_ID', 'symboling', 'enginelocation', 'carlength', 'carwidth' ,'carheight', 'stroke', 'boreratio', 'wheelbase'])
df1
# Out:
#                       CarName fueltype aspiration  doornumber      carbody  \
# 0          alfa-romero giulia      gas        std           2  convertible
# 1         alfa-romero stelvio      gas        std           2  convertible
# 2    alfa-romero Quadrifoglio      gas        std           2    hatchback
# 3                 audi 100 ls      gas        std           4        sedan
# 4                  audi 100ls      gas        std           4        sedan
# ..                        ...      ...        ...         ...          ...
# 200           volvo 145e (sw)      gas        std           4        sedan
# 201               volvo 144ea      gas      turbo           4        sedan
# 202               volvo 244dl      gas        std           4        sedan
# 203                 volvo 246   diesel      turbo           4        sedan
# 204               volvo 264gl      gas      turbo           4        sedan
#
# ...

# %%
df1['cylindernumber']=df['cylindernumber'].apply(w2n.word_to_num)
df1['cylindernumber']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: cylindernumber, Length: 205, dtype: int64

# %%
df1
# Out:
#                       CarName fueltype aspiration  doornumber      carbody  \
# 0          alfa-romero giulia      gas        std           2  convertible
# 1         alfa-romero stelvio      gas        std           2  convertible
# 2    alfa-romero Quadrifoglio      gas        std           2    hatchback
# 3                 audi 100 ls      gas        std           4        sedan
# 4                  audi 100ls      gas        std           4        sedan
# ..                        ...      ...        ...         ...          ...
# 200           volvo 145e (sw)      gas        std           4        sedan
# 201               volvo 144ea      gas      turbo           4        sedan
# 202               volvo 244dl      gas        std           4        sedan
# 203                 volvo 246   diesel      turbo           4        sedan
# 204               volvo 264gl      gas      turbo           4        sedan
#
# ...

# %%
df1['fueltype']=df1['fueltype'].map({'gas':0, 'diesel':1})
df1
# Out:
#                       CarName  fueltype aspiration  doornumber      carbody  \
# 0          alfa-romero giulia         0        std           2  convertible
# 1         alfa-romero stelvio         0        std           2  convertible
# 2    alfa-romero Quadrifoglio         0        std           2    hatchback
# 3                 audi 100 ls         0        std           4        sedan
# 4                  audi 100ls         0        std           4        sedan
# ..                        ...       ...        ...         ...          ...
# 200           volvo 145e (sw)         0        std           4        sedan
# 201               volvo 144ea         0      turbo           4        sedan
# 202               volvo 244dl         0        std           4        sedan
# 203                 volvo 246         1      turbo           4        sedan
# 204               volvo 264gl         0      turbo           4        sedan
#
# ...

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df1.drop('price', axis = 'columns'), df1['price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1428\3983832108.py in ?()
# ----> 1 reg.fit(df1.drop('price', axis = 'columns'), df1['price'])
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
#     615
#     616         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     617
# --> 618         X, y = validate_data(
#     619             self,
# ...
